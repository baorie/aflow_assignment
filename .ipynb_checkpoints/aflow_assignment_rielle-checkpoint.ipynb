# %% [markdown]
# # AFLOW Assignment - Rielle

# %% [markdown]
# My assignment was to create a Jupyter notebook that determines the compound with the lowest formation enthalpy in a binary system using the AFLOW database and the AFLUX API. I was also told to demonstrate that my code works on the Mn-Pd system. My code should recreate results found using AFLOW-CHULL.

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import ConvexHull
from urllib.request import urlopen

elements = ['Mn','Pd']
elements.sort()

SERVER='http://aflowlib.duke.edu'
API='/search/API/?'
SUMMONS="stoichiometry,species,enthalpy_formation_atom,$auid,$aurl,catalog('lib2'),$paging(0)"
response=json.loads(urlopen(SERVER+API+SUMMONS).read().decode('utf-8'))

# %%
response
# Out:
# [{'compound': 'Pt1',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '4.8e-05'},
#  {'compound': 'Sr6',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.00509033'},
#  {'compound': 'Sr1',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '2.5e-05'},
#  {'compound': 'Pt4',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.00799875'},
#  {'compound': 'Pt1',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.091733'},
#  {'compound': 'Sr4',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.127666'},
#  {'compound': 'Sr2',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.960152'},
#  {'compound': 'Sr1',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.004128'},
#  {'compound': 'Pt2',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '1.06346'},
#  {'compound': 'Pt1',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.102991'},
#  {'compound': 'Sr1',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.003051'},
#  {'compound': 'Pt2',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.055882'},
#  {'compound': 'Pt6',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.451323'},
#  {'compound': 'Sr3',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.000798333'},
#  {'compound': 'Pt3',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.450448'},
#  {'compound': 'Sr1',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '-0.000468'},
#  {'compound': 'Pt1',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '6.0e-06'},
#  {'compound': 'Pt2',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.055706'},
#  {'compound': 'Sr2',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.002547'},
#  {'compound': 'Pt1',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '-0.000134'},
#  {'compound': 'Sr2',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.259605'},
#  {'compound': 'Pt2',
#   'stoichiometry': '1',
#   'species': 'Pt',
#   'enthalpy_formation_atom': '0.295689'},
#  {'compound': 'Sr1',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '7.1e-05'},
#  {'compound': 'Sr2',
#   'stoichiometry': '1',
#   'species': 'Sr',
#   'enthalpy_formation_atom': '0.0020935'},
#  {'compound': 'Ru1',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '0.112827'},
#  {'compound': 'Be6',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.0832572'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.086663'},
#  {'compound': 'Ru4',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '0.414922'},
#  {'compound': 'Ru2',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '1.11865'},
#  {'compound': 'Ru1',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '0.619296'},
#  {'compound': 'Be4',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.340809'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '1.63336'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.105997'},
#  {'compound': 'Ru2',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '1.18454'},
#  {'compound': 'Ru1',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '0.619296'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.105427'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.0809125'},
#  {'compound': 'Ru2',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '-0.0021065'},
#  {'compound': 'Ru6',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '1.12578'},
#  {'compound': 'Be3',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.0831087'},
#  {'compound': 'Ru3',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '1.11631'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.083731'},
#  {'compound': 'Ru1',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '0.106567'},
#  {'compound': 'Ru2',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '-0.0021715'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.0013525'},
#  {'compound': 'Ru1',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '0.10657'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.724435'},
#  {'compound': 'Ru2',
#   'stoichiometry': '1',
#   'species': 'Ru',
#   'enthalpy_formation_atom': '1.26681'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.084079'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.001309'},
#  {'compound': 'C1',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '2.63527'},
#  {'compound': 'Au1',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.002282'},
#  {'compound': 'C4',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '0.972784'},
#  {'compound': 'C2',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '0.131118'},
#  {'compound': 'C1',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '4.35055'},
#  {'compound': 'Au4',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.0148315'},
#  {'compound': 'Au2',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.714096'},
#  {'compound': 'Au1',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.02232'},
#  {'compound': 'C2',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '0.131112'},
#  {'compound': 'C1',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '4.35055'},
#  {'compound': 'Au1',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.02232'},
#  {'compound': 'Au2',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '-0.0001635'},
#  {'compound': 'C2',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '3.95965'},
#  {'compound': 'Au3',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '-0.001219'},
#  {'compound': 'C3',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '0.986635'},
#  {'compound': 'Au1',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.00296'},
#  {'compound': 'C1',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '4.55854'},
#  {'compound': 'C2',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '3.95483'},
#  {'compound': 'Au2',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.005627'},
#  {'compound': 'C1',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '4.55984'},
#  {'compound': 'Au2',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.156986'},
#  {'compound': 'C2',
#   'stoichiometry': '1',
#   'species': 'C',
#   'enthalpy_formation_atom': '0.131772'},
#  {'compound': 'Au1',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.000593'},
#  {'compound': 'Au2',
#   'stoichiometry': '1',
#   'species': 'Au',
#   'enthalpy_formation_atom': '0.0056255'},
#  {'compound': 'P1',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.460562'},
#  {'compound': 'Br1',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.137785'},
#  {'compound': 'P4',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '-0.0502867'},
#  {'compound': 'P1',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.641012'},
#  {'compound': 'Br4',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.029701'},
#  {'compound': 'Br2',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.592806'},
#  {'compound': 'Br1',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.585578'},
#  {'compound': 'P1',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.641012'},
#  {'compound': 'Br1',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.585578'},
#  {'compound': 'Br2',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.389765'},
#  {'compound': 'P2',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.347467'},
#  {'compound': 'P3',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.051302'},
#  {'compound': 'Br1',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.617233'},
#  {'compound': 'P1',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.806442'},
#  {'compound': 'P2',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.347467'},
#  {'compound': 'Br2',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.463838'},
#  {'compound': 'P1',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.806442'},
#  {'compound': 'P2',
#   'stoichiometry': '1',
#   'species': 'P',
#   'enthalpy_formation_atom': '0.284799'},
#  {'compound': 'Br1',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.617232'},
#  {'compound': 'Br2',
#   'stoichiometry': '1',
#   'species': 'Br',
#   'enthalpy_formation_atom': '0.463564'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.166028'},
#  {'compound': 'Cl1',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.351855'},
#  {'compound': 'Ta4',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.40624'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.000267'},
#  {'compound': 'Cl4',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '-0.00086125'},
#  {'compound': 'Cl2',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.826355'},
#  {'compound': 'Cl1',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.836427'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.000267'},
#  {'compound': 'Cl1',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.836427'},
#  {'compound': 'Cl2',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.643092'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.278963'},
#  {'compound': 'Cl3',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.100557'},
#  {'compound': 'Cl1',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.896041'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.240648'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.278963'},
#  {'compound': 'Cl2',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.722102'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.240648'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.757834'},
#  {'compound': 'Cl1',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.896023'},
#  {'compound': 'Cl2',
#   'stoichiometry': '1',
#   'species': 'Cl',
#   'enthalpy_formation_atom': '0.722102'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.013502'},
#  {'compound': 'Co6',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.0971135'},
#  {'compound': 'Co1',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.017855'},
#  {'compound': 'Hg4',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0314518'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.004473'},
#  {'compound': 'Co4',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.421681'},
#  {'compound': 'Co2',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '1.27783'},
#  {'compound': 'Co1',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.098143'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.089192'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.004216'},
#  {'compound': 'Hg4',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.08012'},
#  {'compound': 'Co1',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.098142'},
#  {'compound': 'Co2',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.0191035'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0006655'},
#  {'compound': 'Hg6',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.00911333'},
#  {'compound': 'Co3',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.0154203'},
#  {'compound': 'Hg3',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0137023'},
#  {'compound': 'Co1',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.017964'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.017933'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0006655'},
#  {'compound': 'Co2',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '-0.0001755'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.017933'},
#  {'compound': 'Co2',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.536566'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0144725'},
#  {'compound': 'Co1',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '0.017964'},
#  {'compound': 'Co2',
#   'stoichiometry': '1',
#   'species': 'Co',
#   'enthalpy_formation_atom': '-0.000166'},
#  {'compound': 'Y1',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.025868'},
#  {'compound': 'Rh6',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.782681'},
#  {'compound': 'Rh1',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '-0.00014'},
#  {'compound': 'Y4',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.200871'},
#  {'compound': 'Y2',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.124402'},
#  {'compound': 'Y1',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.123763'},
#  {'compound': 'Rh4',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.348134'},
#  {'compound': 'Rh2',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '1.11104'},
#  {'compound': 'Rh1',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.335096'},
#  {'compound': 'Y2',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '1.98495'},
#  {'compound': 'Y1',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.123763'},
#  {'compound': 'Rh1',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.335096'},
#  {'compound': 'Rh2',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.778669'},
#  {'compound': 'Y2',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '-0.000179'},
#  {'compound': 'Y6',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.127923'},
#  {'compound': 'Rh3',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.80541'},
#  {'compound': 'Y3',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.030866'},
#  {'compound': 'Rh1',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '-0.000163'},
#  {'compound': 'Y1',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.025824'},
#  {'compound': 'Y2',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '-0.000179'},
#  {'compound': 'Rh2',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.0361275'},
#  {'compound': 'Y1',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.025814'},
#  {'compound': 'Rh2',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.534915'},
#  {'compound': 'Y2',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.456479'},
#  {'compound': 'Rh1',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '-0.000163'},
#  {'compound': 'Rh2',
#   'stoichiometry': '1',
#   'species': 'Rh',
#   'enthalpy_formation_atom': '0.0361275'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.07346'},
#  {'compound': 'Ca6',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.0159103'},
#  {'compound': 'Ca1',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '-0.00047'},
#  {'compound': 'Hf4',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.299226'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.072864'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.180775'},
#  {'compound': 'Ca4',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.127235'},
#  {'compound': 'Ca2',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '1.04713'},
#  {'compound': 'Ca1',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.015371'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '2.68766'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.18077'},
#  {'compound': 'Ca1',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.015434'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.001724'},
#  {'compound': 'Hf6',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.183025'},
#  {'compound': 'Ca3',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.000212667'},
#  {'compound': 'Hf3',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.0778283'},
#  {'compound': 'Ca1',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '-0.000629'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.07314'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.0017935'},
#  {'compound': 'Ca2',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '-0.0001075'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.073045'},
#  {'compound': 'Ca2',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.257501'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.652022'},
#  {'compound': 'Ca1',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '-0.000922'},
#  {'compound': 'Ca2',
#   'stoichiometry': '1',
#   'species': 'Ca',
#   'enthalpy_formation_atom': '0.0002025'},
#  {'compound': 'Se1',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.2119'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.071648'},
#  {'compound': 'Se1',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.580927'},
#  {'compound': 'Hf4',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.29657'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.179698'},
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.503718'},
#  {'compound': 'Se1',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.580927'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.179698'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.0728675'},
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.360371'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.071564'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.071501'},
#  {'compound': 'Se1',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.722719'},
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.360371'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '-0.000238'},
#  {'compound': 'Se1',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.722719'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.657125'},
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.266546'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.071501'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '-0.0002425'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019423'},
#  {'compound': 'Ag1',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.000126'},
#  {'compound': 'Sn4',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.0709978'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.0354195'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.030074'},
#  {'compound': 'Ag4',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.123845'},
#  {'compound': 'Ag2',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.779177'},
#  {'compound': 'Ag1',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.030307'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '-0.0387985'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.030074'},
#  {'compound': 'Ag1',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.030307'},
#  {'compound': 'Ag2',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.001256'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.017671'},
#  {'compound': 'Ag3',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.00172267'},
#  {'compound': 'Sn3',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.035533'},
#  {'compound': 'Ag1',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.000237'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019468'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.017671'},
#  {'compound': 'Ag2',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.0037295'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019468'},
#  {'compound': 'Ag2',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.242696'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '-0.038779'},
#  {'compound': 'Ag1',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.000237'},
#  {'compound': 'Ag2',
#   'stoichiometry': '1',
#   'species': 'Ag',
#   'enthalpy_formation_atom': '0.0037295'},
#  {'compound': 'Cr4',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '1.04863'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.022339'},
#  {'compound': 'Cr6',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.335827'},
#  {'compound': 'Cr1',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.263268'},
#  {'compound': 'Zn4',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.186944'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0218855'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.082795'},
#  {'compound': 'Cr4',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.474766'},
#  {'compound': 'Cr2',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '2.14949'},
#  {'compound': 'Cr1',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '-0.000829'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.467882'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.082749'},
#  {'compound': 'Cr1',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '-0.00083'},
#  {'compound': 'Cr2',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.338943'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0003255'},
#  {'compound': 'Zn6',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.221697'},
#  {'compound': 'Cr3',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.336384'},
#  {'compound': 'Zn3',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.019365'},
#  {'compound': 'Cr1',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.388952'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021989'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.000178'},
#  {'compound': 'Cr2',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.399612'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021974'},
#  {'compound': 'Cr2',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.729213'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.184159'},
#  {'compound': 'Cr1',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.388952'},
#  {'compound': 'Cr2',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.399612'},
#  {'compound': 'Ir1',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '-8.7e-05'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.0354105'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.030074'},
#  {'compound': 'Ir2',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '1.0018'},
#  {'compound': 'Ir1',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '0.611369'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '-0.0387985'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.030074'},
#  {'compound': 'Ir1',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '0.611369'},
#  {'compound': 'Ir2',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '0.981667'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.017672'},
#  {'compound': 'Ir1',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '-7.8e-05'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019468'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.017671'},
#  {'compound': 'Ir2',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '0.072653'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019468'},
#  {'compound': 'Ir2',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '0.665933'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '-0.0387775'},
#  {'compound': 'Ir1',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '-7.8e-05'},
#  {'compound': 'Ir2',
#   'stoichiometry': '1',
#   'species': 'Ir',
#   'enthalpy_formation_atom': '0.072654'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.165677'},
#  {'compound': 'Bi1',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.176596'},
#  {'compound': 'Ta4',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.406295'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.242057'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.000118'},
#  {'compound': 'Bi4',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.0376052'},
#  {'compound': 'Bi2',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.190716'},
#  {'compound': 'Bi1',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.128313'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '2.87411'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.000118'},
#  {'compound': 'Bi1',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.128313'},
#  {'compound': 'Bi2',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.0002625'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.279461'},
#  {'compound': 'Bi3',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.0412423'},
#  {'compound': 'Ta3',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.242446'},
#  {'compound': 'Bi1',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.181832'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.240534'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.279461'},
#  {'compound': 'Bi2',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.138239'},
#  {'compound': 'Ta1',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.240534'},
#  {'compound': 'Bi2',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.198632'},
#  {'compound': 'Ta2',
#   'stoichiometry': '1',
#   'species': 'Ta',
#   'enthalpy_formation_atom': '0.758426'},
#  {'compound': 'Bi1',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.181831'},
#  {'compound': 'Bi2',
#   'stoichiometry': '1',
#   'species': 'Bi',
#   'enthalpy_formation_atom': '0.138239'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.159818'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.014304'},
#  {'compound': 'Te4',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.192393'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.307199'},
#  {'compound': 'Hg4',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.03504'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0863145'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.005038'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.418903'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.3072'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.005038'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0191905'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.179153'},
#  {'compound': 'Te3',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '-6.8e-05'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.018151'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.413265'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.179153'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0008815'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.413264'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.018148'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0006485'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.030074'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001503'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '-0.038762'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.030074'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001494'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.0026575'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.017672'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001181'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019468'},
#  {'compound': 'Sn2',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.017672'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.0010665'},
#  {'compound': 'Sn1',
#   'stoichiometry': '1',
#   'species': 'Sn',
#   'enthalpy_formation_atom': '0.019468'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.073697'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.002101'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001203'},
#  {'compound': 'Zr1',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.03954'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '-0.000117'},
#  {'compound': 'Zr2',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.040868'},
#  {'compound': 'Zr1',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.080662'},
#  {'compound': 'In2',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.337716'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.011565'},
#  {'compound': 'Zr2',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '2.38706'},
#  {'compound': 'Zr1',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.080668'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.011602'},
#  {'compound': 'In2',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.013427'},
#  {'compound': 'Zr2',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '-0.000327'},
#  {'compound': 'Zr3',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.041445'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.000708'},
#  {'compound': 'Zr1',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.039332'},
#  {'compound': 'Zr2',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '-0.000337'},
#  {'compound': 'In2',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.0059395'},
#  {'compound': 'Zr1',
#   'stoichiometry': '1',
#   'species': 'Zr',
#   'enthalpy_formation_atom': '0.039332'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.00078'},
#  {'compound': 'In2',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.005949'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '-0.000124'},
#  {'compound': 'In4',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.062981'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.011595'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '1.63232'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.099637'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.011602'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.099637'},
#  {'compound': 'In2',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.005949'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '4.0e-06'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.081005'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.000708'},
#  {'compound': 'In2',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.0059485'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '-0.0003225'},
#  {'compound': 'In1',
#   'stoichiometry': '1',
#   'species': 'In',
#   'enthalpy_formation_atom': '0.000708'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.723682'},
#  {'compound': 'Be1',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '0.081005'},
#  {'compound': 'Be2',
#   'stoichiometry': '1',
#   'species': 'Be',
#   'enthalpy_formation_atom': '-0.000323'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.005213'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.331094'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001503'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.370927'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.005276'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001494'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '-0.0002625'},
#  {'compound': 'Tl3',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.019377'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001181'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.019957'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '-0.000436'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.0010665'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.02007'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.073697'},
#  {'compound': 'Na1',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.00107'},
#  {'compound': 'Na2',
#   'stoichiometry': '1',
#   'species': 'Na',
#   'enthalpy_formation_atom': '0.001203'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.022399'},
#  {'compound': 'Sc6',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.110581'},
#  {'compound': 'Sc1',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.048041'},
#  {'compound': 'Zn4',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.187255'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021887'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.082795'},
#  {'compound': 'Sc4',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.196142'},
#  {'compound': 'Sc2',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '1.98349'},
#  {'compound': 'Sc1',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.104631'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.467431'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.082795'},
#  {'compound': 'Sc1',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.104638'},
#  {'compound': 'Sc2',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.051129'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.000177'},
#  {'compound': 'Zn6',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.221699'},
#  {'compound': 'Sc3',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.0551483'},
#  {'compound': 'Zn3',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0196453'},
#  {'compound': 'Sc1',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.048029'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021989'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0003255'},
#  {'compound': 'Sc2',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '9.0e-06'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021974'},
#  {'compound': 'Sc2',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.412604'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.184143'},
#  {'compound': 'Sc1',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '0.048029'},
#  {'compound': 'Sc2',
#   'stoichiometry': '1',
#   'species': 'Sc',
#   'enthalpy_formation_atom': '9.0e-06'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.017713'},
#  {'compound': 'Cd6',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.0469122'},
#  {'compound': 'Cd1',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.004915'},
#  {'compound': 'Tl4',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.151536'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.005486'},
#  {'compound': 'Cd4',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.0508085'},
#  {'compound': 'Cd2',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.338263'},
#  {'compound': 'Cd1',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.053363'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.369255'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.005539'},
#  {'compound': 'Cd1',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.053385'},
#  {'compound': 'Cd2',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.003153'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '-0.0030755'},
#  {'compound': 'Tl6',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '-0.000693833'},
#  {'compound': 'Cd3',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '-0.010113'},
#  {'compound': 'Tl3',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.0120217'},
#  {'compound': 'Cd1',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.006289'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.017945'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '-0.003076'},
#  {'compound': 'Cd2',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '-0.0011'},
#  {'compound': 'Tl1',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.018097'},
#  {'compound': 'Cd2',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.101529'},
#  {'compound': 'Tl2',
#   'stoichiometry': '1',
#   'species': 'Tl',
#   'enthalpy_formation_atom': '0.0890515'},
#  {'compound': 'Cd1',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '0.006324'},
#  {'compound': 'Cd2',
#   'stoichiometry': '1',
#   'species': 'Cd',
#   'enthalpy_formation_atom': '-0.0010695'},
#  {'compound': 'Cr4',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '1.04863'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.07685'},
#  {'compound': 'Cr6',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.335846'},
#  {'compound': 'Cr1',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.263268'},
#  {'compound': 'Mn4',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.528114'},
#  {'compound': 'Mn2',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.0781835'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.142427'},
#  {'compound': 'Cr4',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '0.474766'},
#  {'compound': 'Cr2',
#   'stoichiometry': '1',
#   'species': 'Cr',
#   'enthalpy_formation_atom': '2.14949'},
#  {'compound': 'Mn20',
#   'stoichiometry': '1',
#   'species': 'Mn',
# ...
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.360371'},
#  {'compound': 'Y1',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.02584'},
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.266546'},
#  {'compound': 'Y2',
#   'stoichiometry': '1',
#   'species': 'Y',
#   'enthalpy_formation_atom': '0.456603'},
#  {'compound': 'Se1',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.722719'},
#  {'compound': 'Se2',
#   'stoichiometry': '1',
#   'species': 'Se',
#   'enthalpy_formation_atom': '0.360371'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.159818'},
#  {'compound': 'Nb1',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.144418'},
#  {'compound': 'Te4',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.192393'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.041448'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.307199'},
#  {'compound': 'Nb2',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '2.5525'},
#  {'compound': 'Nb1',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '-0.000665'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.418903'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.3072'},
#  {'compound': 'Nb1',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '-0.000664'},
#  {'compound': 'Nb2',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.270148'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.179153'},
#  {'compound': 'Nb3',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.270322'},
#  {'compound': 'Te3',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '-6.8e-05'},
#  {'compound': 'Nb1',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.324951'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.413265'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.179153'},
#  {'compound': 'Nb2',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.297133'},
#  {'compound': 'Te1',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.413264'},
#  {'compound': 'Nb2',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.603926'},
#  {'compound': 'Te2',
#   'stoichiometry': '1',
#   'species': 'Te',
#   'enthalpy_formation_atom': '0.172007'},
#  {'compound': 'Nb1',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.324949'},
#  {'compound': 'Nb2',
#   'stoichiometry': '1',
#   'species': 'Nb',
#   'enthalpy_formation_atom': '0.297131'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.022339'},
#  {'compound': 'Pd6',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.507753'},
#  {'compound': 'Pd1',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.001204'},
#  {'compound': 'Zn4',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.187255'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0218855'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.082795'},
#  {'compound': 'Pd4',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.258911'},
#  {'compound': 'Pd2',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '1.12625'},
#  {'compound': 'Pd1',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.043192'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.467882'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.082749'},
#  {'compound': 'Pd1',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.043192'},
#  {'compound': 'Pd2',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.003468'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0003255'},
#  {'compound': 'Zn6',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.221699'},
#  {'compound': 'Pd3',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.00241067'},
#  {'compound': 'Zn3',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.0196453'},
#  {'compound': 'Pd1',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.000653'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021989'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.000178'},
#  {'compound': 'Pd2',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.024976'},
#  {'compound': 'Zn1',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.021974'},
#  {'compound': 'Pd2',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.347265'},
#  {'compound': 'Zn2',
#   'stoichiometry': '1',
#   'species': 'Zn',
#   'enthalpy_formation_atom': '0.184159'},
#  {'compound': 'Pd1',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.00069'},
#  {'compound': 'Pd2',
#   'stoichiometry': '1',
#   'species': 'Pd',
#   'enthalpy_formation_atom': '0.0249725'},
#  {'compound': 'V1',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.092758'},
#  {'compound': 'Os6',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.707214'},
#  {'compound': 'Os1',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.137524'},
#  {'compound': 'V4',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.257715'},
#  {'compound': 'V2',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.245552'},
#  {'compound': 'V1',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.000185'},
#  {'compound': 'Os4',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.514585'},
#  {'compound': 'Os2',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '1.28176'},
#  {'compound': 'Os1',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.885686'},
#  {'compound': 'V2',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '2.29486'},
#  {'compound': 'V1',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.000185'},
#  {'compound': 'Os1',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.885686'},
#  {'compound': 'Os2',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.886846'},
#  {'compound': 'V2',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.253566'},
#  {'compound': 'V6',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.243925'},
#  {'compound': 'Os3',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.138603'},
#  {'compound': 'V3',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.243575'},
#  {'compound': 'Os1',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.137042'},
#  {'compound': 'V1',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.242813'},
#  {'compound': 'V2',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.253564'},
#  {'compound': 'Os2',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '-0.00033'},
#  {'compound': 'V1',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.242829'},
#  {'compound': 'Os2',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '1.28578'},
#  {'compound': 'V2',
#   'stoichiometry': '1',
#   'species': 'V',
#   'enthalpy_formation_atom': '0.475052'},
#  {'compound': 'Os1',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '0.137042'},
#  {'compound': 'Os2',
#   'stoichiometry': '1',
#   'species': 'Os',
#   'enthalpy_formation_atom': '-0.00033'},
#  {'compound': 'Tc1',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.069113'},
#  {'compound': 'Hg6',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0093625'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.013502'},
#  {'compound': 'Tc4',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.578429'},
#  {'compound': 'Tc2',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.0701525'},
#  {'compound': 'Tc1',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.260758'},
#  {'compound': 'Hg4',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0314518'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0891915'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.004473'},
#  {'compound': 'Tc2',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '1.437'},
#  {'compound': 'Tc1',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.260759'},
#  {'compound': 'Tc4',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '1.0698'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.004216'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0191905'},
#  {'compound': 'Tc2',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '8.15e-05'},
#  {'compound': 'Tc6',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.262889'},
#  {'compound': 'Hg3',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0137023'},
#  {'compound': 'Tc3',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.0680207'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.017928'},
#  {'compound': 'Tc1',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.069061'},
#  {'compound': 'Tc2',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '8.15e-05'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0006535'},
#  {'compound': 'Tc1',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.069061'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0144725'},
#  {'compound': 'Tc2',
#   'stoichiometry': '1',
#   'species': 'Tc',
#   'enthalpy_formation_atom': '0.79504'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.017928'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0006655'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.014125'},
#  {'compound': 'Hg4',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0350643'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.006937'},
#  {'compound': 'B4',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-6.41931'},
#  {'compound': 'B1',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-4.97651'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0863145'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.005038'},
#  {'compound': 'B1',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-4.97651'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0006485'},
#  {'compound': 'B3',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-5.65833'},
#  {'compound': 'Hg3',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.0195673'},
#  {'compound': 'B1',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-5.33556'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.018148'},
#  {'compound': 'Hg2',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '-0.0008815'},
#  {'compound': 'B2',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-5.97806'},
#  {'compound': 'Hg1',
#   'stoichiometry': '1',
#   'species': 'Hg',
#   'enthalpy_formation_atom': '0.018151'},
#  {'compound': 'B1',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-5.33556'},
#  {'compound': 'B2',
#   'stoichiometry': '1',
#   'species': 'B',
#   'enthalpy_formation_atom': '-5.97806'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.07685'},
#  {'compound': 'Hf6',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.183316'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.072145'},
#  {'compound': 'Mn4',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.528114'},
#  {'compound': 'Mn2',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.0781835'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.142427'},
#  {'compound': 'Hf4',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.299226'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '2.68536'},
#  {'compound': 'Mn20',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.0425135'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.179869'},
#  {'compound': 'Mn2',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '1.40668'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.142427'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.179869'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.072831'},
#  {'compound': 'Mn29',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '-0.00398776'},
#  {'compound': 'Mn2',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.046757'},
#  {'compound': 'Mn6',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.0759'},
#  {'compound': 'Hf3',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.0765593'},
#  {'compound': 'Mn3',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.0816693'},
#  {'compound': 'Hf1',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.071414'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.07667'},
#  {'compound': 'Mn2',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.046757'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '-0.000158'},
#  {'compound': 'Mn1',
#   'stoichiometry': '1',
#   'species': 'Mn',
#   'enthalpy_formation_atom': '0.076678'},
#  {'compound': 'Hf2',
#   'stoichiometry': '1',
#   'species': 'Hf',
#   'enthalpy_formation_atom': '0.652584'},
#  ...]

# %% [markdown]
# Once I entered a query that isolated information about the stoichiometry, species, and formation enthalpy of all `aflowlib_entries` in `lib2`, the library that contains all binary compounds, I narrowed down the list of dictionary items to all items that contained all entries in my list `elements`. These items were then stored in a list of dictionary items called `binary_compounds`.

# %%
binary_compounds = [] # We're going to assume that we're given only 2 elements
for i in range(len(response)):
    all_elements = True
    for entry in elements:
        if entry not in response[i]['species']:
            all_elements = False
    if all_elements:
        binary_compounds.append(response[i])

# %%
binary_compounds
# Out:
# [{'compound': 'Mn2Pd44',
#   'stoichiometry': '0.0434782609,0.956521739',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.140106'},
#  {'compound': 'Mn2Pd26',
#   'stoichiometry': '0.0714285714,0.928571429',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.251998'},
#  {'compound': 'Mn1Pd8',
#   'stoichiometry': '0.111111111,0.888888889',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.124903'},
#  {'compound': 'Mn1Pd7',
#   'stoichiometry': '0.125,0.875',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.130966'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.17459'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.127268'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.147153'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.065621'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.160799'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.100001'},
#  {'compound': 'Mn1Pd5',
#   'stoichiometry': '0.166666667,0.833333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.124152'},
#  {'compound': 'Mn5Pd24',
#   'stoichiometry': '0.172413793,0.827586207',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0291466'},
#  {'compound': 'Mn1Pd4',
#   'stoichiometry': '0.2,0.8',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.595792'},
#  {'compound': 'Mn1Pd4',
#   'stoichiometry': '0.2,0.8',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.229626'},
#  {'compound': 'Mn1Pd4',
#   'stoichiometry': '0.2,0.8',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.180849'},
#  {'compound': 'Mn4Pd16',
#   'stoichiometry': '0.2,0.8',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.213902'},
#  {'compound': 'Mn4Pd12',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.192009'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.176592'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.23514'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0900945'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0776058'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '1.26747'},
#  {'compound': 'Mn2Pd6',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0537957'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.17346'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.16948'},
#  {'compound': 'Mn2Pd6',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.225585'},
#  {'compound': 'Mn2Pd6',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.213582'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.182834'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.158894'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0876955'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.150749'},
#  {'compound': 'Mn2Pd6',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.224832'},
#  {'compound': 'Mn2Pd6',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.213981'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.145405'},
#  {'compound': 'Mn2Pd6',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.203542'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.233655'},
#  {'compound': 'Mn6Pd18',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.206419'},
#  {'compound': 'Mn4Pd12',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.213914'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.206268'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.171407'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.168308'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.158723'},
#  {'compound': 'Mn6Pd18',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.224853'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.206538'},
#  {'compound': 'Mn1Pd3',
#   'stoichiometry': '0.25,0.75',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.159496'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.122501'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.13183'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.203493'},
#  {'compound': 'Mn8Pd16',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0555626'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.172783'},
#  {'compound': 'Mn8Pd16',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0859654'},
#  {'compound': 'Mn3Pd6',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.050336'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.141323'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.172783'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.07212'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.204773'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.033269'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.155678'},
#  {'compound': 'Mn4Pd8',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.372728'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.137097'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.140251'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.206343'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.401884'},
#  {'compound': 'Mn4Pd8',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.062896'},
#  {'compound': 'Mn4Pd8',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.239827'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0736685'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0334252'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.211158'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.172282'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.221576'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.195411'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.010631'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.206818'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.206903'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.158559'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.207113'},
#  {'compound': 'Mn4Pd8',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.198572'},
#  {'compound': 'Mn4Pd8',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.00983475'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.195379'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.12436'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.203049'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.105987'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.191259'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.198846'},
#  {'compound': 'Mn4Pd8',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.251933'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.210866'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0892555'},
#  {'compound': 'Mn1Pd2',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.205777'},
#  {'compound': 'Mn2Pd4',
#   'stoichiometry': '0.333333333,0.666666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.173166'},
#  {'compound': 'Mn3Pd5',
#   'stoichiometry': '0.375,0.625',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.251527'},
#  {'compound': 'Mn6Pd10',
#   'stoichiometry': '0.375,0.625',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.117435'},
#  {'compound': 'Mn6Pd10',
#   'stoichiometry': '0.375,0.625',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.104181'},
#  {'compound': 'Mn2Pd3',
#   'stoichiometry': '0.4,0.6',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0881096'},
#  {'compound': 'Mn4Pd6',
#   'stoichiometry': '0.4,0.6',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.178901'},
#  {'compound': 'Mn2Pd3',
#   'stoichiometry': '0.4,0.6',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.037126'},
#  {'compound': 'Mn12Pd17',
#   'stoichiometry': '0.413793103,0.586206897',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0385972'},
#  {'compound': 'Mn3Pd4',
#   'stoichiometry': '0.428571429,0.571428571',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.105088'},
#  {'compound': 'Mn3Pd4',
#   'stoichiometry': '0.428571429,0.571428571',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0873517'},
#  {'compound': 'Mn4Pd5',
#   'stoichiometry': '0.444444444,0.555555556',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.128339'},
#  {'compound': 'Mn8Pd10',
#   'stoichiometry': '0.444444444,0.555555556',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.145601'},
#  {'compound': 'Mn6Pd7',
#   'stoichiometry': '0.461538462,0.538461538',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0484254'},
#  {'compound': 'Mn6Pd6',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0164212'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.053204'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.130774'},
#  {'compound': 'Mn3Pd3',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.117423'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.129076'},
#  {'compound': 'Mn6Pd6',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.314776'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0202245'},
#  {'compound': 'Mn4Pd4',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.226503'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.180611'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.054357'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.314544'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.552513'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0736302'},
#  {'compound': 'Mn3Pd3',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.17606'},
#  {'compound': 'Mn4Pd4',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.326611'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.180135'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.577268'},
#  {'compound': 'Mn4Pd4',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.113133'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.127885'},
#  {'compound': 'Mn12Pd12',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0799895'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.070944'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0264422'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.196324'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.193836'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.17469'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.026858'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.196079'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0266885'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0490127'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.1304'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0747215'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.173292'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.029713'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0144905'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.037448'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.197015'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.841218'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.182693'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.290017'},
#  {'compound': 'Mn3Pd3',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.153901'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0249292'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0601903'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.299059'},
#  {'compound': 'Mn4Pd4',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.113529'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.196444'},
#  {'compound': 'Mn1Pd1',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.197772'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.129302'},
#  {'compound': 'Mn2Pd2',
#   'stoichiometry': '0.5,0.5',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.196072'},
#  {'compound': 'Mn7Pd6',
#   'stoichiometry': '0.538461538,0.461538462',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0309772'},
#  {'compound': 'Mn5Pd4',
#   'stoichiometry': '0.555555556,0.444444444',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.118419'},
#  {'compound': 'Mn10Pd8',
#   'stoichiometry': '0.555555556,0.444444444',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0251165'},
#  {'compound': 'Mn4Pd3',
#   'stoichiometry': '0.571428571,0.428571429',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.19118'},
#  {'compound': 'Mn4Pd3',
#   'stoichiometry': '0.571428571,0.428571429',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.05337'},
#  {'compound': 'Mn17Pd12',
#   'stoichiometry': '0.586206897,0.413793103',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0715024'},
#  {'compound': 'Mn3Pd2',
#   'stoichiometry': '0.6,0.4',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.230572'},
#  {'compound': 'Mn6Pd4',
#   'stoichiometry': '0.6,0.4',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0380949'},
#  {'compound': 'Mn3Pd2',
#   'stoichiometry': '0.6,0.4',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.129899'},
#  {'compound': 'Mn5Pd3',
#   'stoichiometry': '0.625,0.375',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0152826'},
#  {'compound': 'Mn10Pd6',
#   'stoichiometry': '0.625,0.375',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0986365'},
#  {'compound': 'Mn10Pd6',
#   'stoichiometry': '0.625,0.375',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0951484'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.13568'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0965543'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.0266445'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.158247'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.18519'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.125615'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '-0.00890333'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.123002'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0938067'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0961627'},
#  {'compound': 'Mn16Pd8',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0465303'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.132936'},
#  {'compound': 'Mn8Pd4',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0833136'},
#  {'compound': 'Mn8Pd4',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.130465'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.184666'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.131765'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0965957'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.154908'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.253469'},
#  {'compound': 'Mn6Pd3',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.2421'},
#  {'compound': 'Mn8Pd4',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.984867'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.095872'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.254911'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0948115'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.253205'},
#  {'compound': 'Mn16Pd8',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0727119'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.367169'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.198694'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0737397'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.157579'},
#  {'compound': 'Mn8Pd4',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.028959'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.381446'},
#  {'compound': 'Mn8Pd4',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.493291'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.096649'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.49381'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.253767'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.094853'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.170863'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.141198'},
#  {'compound': 'Mn2Pd1',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.123851'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.251188'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.157579'},
#  {'compound': 'Mn4Pd2',
#   'stoichiometry': '0.666666667,0.333333333',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0283997'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.259366'},
#  {'compound': 'Mn6Pd2',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.194766'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.00418725'},
#  {'compound': 'Mn6Pd2',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.227035'},
#  {'compound': 'Mn18Pd6',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.143957'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.132565'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.225237'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '1.23112'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.203909'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.275947'},
#  {'compound': 'Mn18Pd6',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.184154'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.175079'},
#  {'compound': 'Mn6Pd2',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.107495'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0087435'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.221826'},
#  {'compound': 'Mn12Pd4',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.230163'},
#  {'compound': 'Mn12Pd4',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.146173'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.11974'},
#  {'compound': 'Mn6Pd2',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.158756'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0057345'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0358615'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.196092'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.202319'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.004645'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.203991'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.263214'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.22367'},
#  {'compound': 'Mn6Pd2',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.045071'},
#  {'compound': 'Mn3Pd1',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.242732'},
#  {'compound': 'Mn6Pd2',
#   'stoichiometry': '0.75,0.25',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.248307'},
#  {'compound': 'Mn4Pd1',
#   'stoichiometry': '0.8,0.2',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.891085'},
#  {'compound': 'Mn4Pd1',
#   'stoichiometry': '0.8,0.2',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.177461'},
#  {'compound': 'Mn4Pd1',
#   'stoichiometry': '0.8,0.2',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.331511'},
#  {'compound': 'Mn16Pd4',
#   'stoichiometry': '0.8,0.2',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.237665'},
#  {'compound': 'Mn24Pd5',
#   'stoichiometry': '0.827586207,0.172413793',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0266779'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.123807'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0860495'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.119677'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.0349578'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.116688'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.353283'},
#  {'compound': 'Mn5Pd1',
#   'stoichiometry': '0.833333333,0.166666667',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.12075'},
#  {'compound': 'Mn7Pd1',
#   'stoichiometry': '0.875,0.125',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.169398'},
#  {'compound': 'Mn8Pd1',
#   'stoichiometry': '0.888888889,0.111111111',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.126171'},
#  {'compound': 'Mn26Pd2',
#   'stoichiometry': '0.928571429,0.0714285714',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.296006'},
#  {'compound': 'Mn44Pd2',
#   'stoichiometry': '0.956521739,0.0434782609',
#   'species': 'Mn,Pd',
#   'enthalpy_formation_atom': '0.121583'}]

# %% [markdown]
# I then calculated the convex hull using the atomic ratios of Manganese and formation enthalpies in the `binary_compounds` list to find the atomic ratios and formation enthalpies of stable compounds (with the help of [SciPy docs](https://docs.scipy.org/doc/scipy/reference/generated/scipy.spatial.ConvexHull.html)).
#
# For simplicity, I left the formation enthalpy as electron volts per atom (rather than meV) and the atomic ratio as decimals.

# %%
plt.figure(figsize=(20,10))
x = [float(compound['stoichiometry'].split(',')[0]) for compound in binary_compounds]
y = [float(compound['enthalpy_formation_atom']) for compound in binary_compounds]
points = np.array([x, y], dtype=np.float64).transpose()
hull = ConvexHull(points)
plt.xlabel('Atomic Ratio Manganese', fontsize=16)
plt.ylabel('eV/atom', fontsize=16)
plt.plot(points[:,0], points[:,1], 'rx')
stable_ratio = points[hull.vertices,0]
stable_enthalpy = points[hull.vertices,1]
plt.plot(stable_ratio, stable_enthalpy, 'b-')
plt.axis([0, 1, -0.3, 0.1])
plt.text(0,-0.33, elements[0], fontsize=16)
plt.text(0.99, -0.33, elements[1], fontsize=16)
plt.plot(0.333333333, -0.251933, marker='x', markersize=10, color='black')
plt.show()

# %% [markdown]
# Using `stable_ratio` and `stable_enthalpy`, I calculated the minimum stable enthalpy to find the lowest formation enthalpy in a binary system, and found it's corresponding atomic ratio of Manganese.

# %%
stable_ratio_list = stable_ratio.tolist()
stable_enthalpy_list = stable_enthalpy.tolist()
ls_enthalpy = min(stable_enthalpy_list) # lowest stable enthalpy
ls_ratio = stable_ratio_list[stable_enthalpy_list.index(ls_enthalpy)]
print(ls_ratio, ls_enthalpy)
# Out:
# 0.333333333 -0.251933

# %% [markdown]
# The lowest formation enthalpy is thus found at `0.333333333` Manganese and `-0.251933` eV/atom, which is noted on the graph with a black 'X'. In this case, the compound with the lowest formation enthalpy is Mn4Pd8 is the 84th element in the `binary_compound` list.

# %%
ls_index = y.index(ls_enthalpy)
binary_compounds[ls_index]
# Out:
# {'compound': 'Mn4Pd8',
#  'stoichiometry': '0.333333333,0.666666667',
#  'species': 'Mn,Pd',
#  'enthalpy_formation_atom': '-0.251933'}
